# %%
# !git clone https://github.com/sushant097/TSAI-ERAv1-Assignments.git
# Out:
# Cloning into 'TSAI-ERAv1-Assignments'...
# remote: Enumerating objects: 1262, done.
# remote: Counting objects: 100% (1262/1262), done.
# remote: Compressing objects: 100% (241/241), done.
# remote: Total 1262 (delta 1058), reused 1217 (delta 1013), pack-reused 0
# Receiving objects: 100% (1262/1262), 10.81 MiB | 25.81 MiB/s, done.
# Resolving deltas: 100% (1058/1058), done.

# %%
# !ls /kaggle/working/
# Out:
# TSAI-ERAv1-Assignments	__notebook__.ipynb

# %%
# %cd /kaggle/working/TSAI-ERAv1-Assignments/Session16
# Out:
# /kaggle/working/TSAI-ERAv1-Assignments/Session16

# %%
# !pip install -r requirements.txt --quiet

# %%
from main import *

main(train = True)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ...
# Generating train split:   0%|          | 0/127085 [00:00<?, ? examples/s]
# Dataset opus_books downloaded and prepared to /root/.cache/huggingface/datasets/opus_books/en-fr/1.0.0/e8f950a4f32dc39b7f9088908216cd2d7e21ac35f893d04d39eb594746af2daf. Subsequent calls will reuse this data.
# Length of filtered dataset: 120677
# Train Dataset size: 108609
# Validation Dataset Size: 12068
# Max length of source sentence: 150
# Max length of target sentence: 159
# Source Tokenizer Vocab Size : 30000
# Target Tokenizer Vocab Size : 30000
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch : 0
# ----------------------------------------------------------------------
# ...
